# %%
import wikipediaapi
import os

# Initialize Wikipedia API with a descriptive user agent
wiki = wikipediaapi.Wikipedia(
    user_agent="RealMadridDatasetBot/1.0 (contact: your_email@example.com)",
    language='en'
)

# List of Real Madrid related topics to scrape
topics = ["Real Madrid CF", "Santiago Bernabéu Stadium", "La Fábrica"]

# Create a folder for individual files
if not os.path.exists('individual_files'):
    os.makedirs('individual_files')

for topic in topics:
    page = wiki.page(topic)
    if page.exists():
        # Clean the filename and save the text content
        filename = f"individual_files/{topic.replace(' ', '_').lower()}.txt"
        with open(filename, "w", encoding="utf-8") as f:
            f.write(page.text)
        print(f"Saved: {filename}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import wikipediaapi
#       2 import os
#       4 # Initialize Wikipedia API with a descriptive user agent
#
# ModuleNotFoundError: No module named 'wikipediaapi'

# %%
pip install wikipedia-Api
# Out:
# ...
#
# ...
#
#   Attempting uninstall: tenacity
#
#     Found existing installation: tenacity 9.0.0
#
#     Uninstalling tenacity-9.0.0:
#
#       Successfully uninstalled tenacity-9.0.0
#
#    ---------------------------------------- 0/3 [tenacity]
#   Attempting uninstall: click
#    ---------------------------------------- 0/3 [tenacity]
#     Found existing installation: click 8.0.1
#    ---------------------------------------- 0/3 [tenacity]
#     Uninstalling click-8.0.1:
#    ---------------------------------------- 0/3 [tenacity]
#       Successfully uninstalled click-8.0.1
#    ---------------------------------------- 0/3 [tenacity]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    ------------- -------------------------- 1/3 [click]
#    -------------------------- ------------- 2/3 [wikipedia-Api]
#    -------------------------- ------------- 2/3 [wikipedia-Api]
# ...

# %%
install Wikipedia-Api
# Out:
#   Cell In[9], line 1
#     install Wikipedia-Api
#             ^
# SyntaxError: invalid syntax

# %%
import wikipediaapi
import os

# Initialize Wikipedia API with a descriptive user agent
wiki = wikipediaapi.Wikipedia(
    user_agent="RealMadridDatasetBot/1.0 (contact: your_email@example.com)",
    language='en'
)

# List of Real Madrid related topics to scrape
topics = ["Real Madrid CF", "Santiago Bernabéu Stadium", "La Fábrica"]

# Create a folder for individual files
if not os.path.exists('individual_files'):
    os.makedirs('individual_files')

for topic in topics:
    page = wiki.page(topic)
    if page.exists():
        # Clean the filename and save the text content
        filename = f"individual_files/{topic.replace(' ', '_').lower()}.txt"
        with open(filename, "w", encoding="utf-8") as f:
            f.write(page.text)
        print(f"Saved: {filename}")
# Out:
# Saved: individual_files/real_madrid_cf.txt
# Saved: individual_files/santiago_bernabéu_stadium.txt
# Saved: individual_files/la_fábrica.txt

# %%
folder_path = 'individual_files'
master_file = 'real_madrid_master_dataset.txt'

with open(master_file, 'w', encoding='utf-8') as outfile:
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-8') as infile:
                outfile.write(f"--- SOURCE: {filename} ---\n")
                outfile.write(infile.read() + "\n\n")

print(f"Master file created at: {os.path.abspath(master_file)}")
# Out:
# Master file created at: C:\Users\Dell\real_madrid_master_dataset.txt

# %%
import os; print(os.getcwd())
# Out:
# C:\Users\Dell
